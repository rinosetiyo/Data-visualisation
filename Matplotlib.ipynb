# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\rinos\appdata\local\programs\python\python39\lib\site-packages (3.6.2)
# Requirement already satisfied: numpy>=1.19 in c:\users\rinos\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.23.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\rinos\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rinos\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rinos\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\rinos\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rinos\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\rinos\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rinos\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rinos\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\rinos\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib

matplotlib.__version__
# Out:
# '3.6.2'

# %%
import matplotlib.pyplot as plt

# %%
x = [2,4,6,8,10]
y = [8,1,6,5,6]

# membuat object visual
plt.plot(x,y)

# %%
import numpy as np

x = np.linspace(0, 30, 100)
y1 = np.cos(x*2)
y2 = np.cos(x)
y3 = np.sin(x/3)
y4 = np.sin(x)

fig, ax = plt.subplots(figsize=(10,6))

ax.plot(x, y1, color='red')
ax.plot(x, y2, color='blue')
ax.plot(x, y3, color='green')
ax.plot(x, y4, color='black')

plt.show()

# %%
# mengecek style yang tersedia
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('tableau-colorblind10')

x = np.linspace(0, 30, 100)
y1 = np.cos(x*2)
y2 = np.cos(x)
y3 = np.sin(x/3)
y4 = np.sin(x)

fig, ax = plt.subplots(figsize=(10,6))

ax.plot(x, y1)
ax.plot(x, y2)
ax.plot(x, y3)
ax.plot(x, y4)

plt.show()

# %%
plt.style.use('ggplot')

x = np.linspace(0, 30, 100)
y1 = np.cos(x*2)
y2 = np.cos(x)
y3 = np.sin(x/3)
y4 = np.sin(x)

fig, ax = plt.subplots(figsize=(10,6))

ax.plot(x, y1)
ax.plot(x, y2)
ax.plot(x, y3)
ax.plot(x, y4)

plt.show()

# %%
plt.style.use('ggplot')

x = np.linspace(0, 30, 100)
y1 = np.cos(x*2)
y2 = np.cos(x)
y3 = np.sin(x/3)
y4 = np.sin(x)

fig, ax = plt.subplots(figsize=(10,6))

ax.plot(x, y1)
ax.plot(x, y2)
ax.plot(x, y3)
ax.plot(x, y4)

# menyimpan gambar
fig.savefig('visualisasi.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("who_suicide_statistics.csv")
df.head(10)
# Out:
#    country  year     sex          age  suicides_no  population
# 0  Albania  1985  female  15-24 years          NaN    277900.0
# 1  Albania  1985  female  25-34 years          NaN    246800.0
# 2  Albania  1985  female  35-54 years          NaN    267500.0
# 3  Albania  1985  female   5-14 years          NaN    298300.0
# 4  Albania  1985  female  55-74 years          NaN    138700.0
# 5  Albania  1985  female    75+ years          NaN     34200.0
# 6  Albania  1985    male  15-24 years          NaN    301400.0
# 7  Albania  1985    male  25-34 years          NaN    264200.0
# 8  Albania  1985    male  35-54 years          NaN    296700.0
# 9  Albania  1985    male   5-14 years          NaN    325800.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43776 entries, 0 to 43775
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      43776 non-null  object
#  1   year         43776 non-null  int64
#  2   sex          43776 non-null  object
#  3   age          43776 non-null  object
#  4   suicides_no  41520 non-null  float64
#  5   population   38316 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 2.0+ MB

# %%
# mengubah tipe data kolom suicide_no

df['suicides_no'] = df['suicides_no'].astype('Int64')
df['suicides_no'].dtypes
# Out:
# Int64Dtype()

# %%
df_year = df.groupby(['year'])[['suicides_no']].sum()
df_year
# Out:
#       suicides_no
# year
# 1979        92790
# 1980       153548
# 1981       178014
# 1982       182893
# 1983       122430
# 1984       124427
# 1985       197533
# 1986       189225
# 1987       186364
# 1988       181416
# 1989       186043
# 1990       205507
# 1991       204756
# 1992       219100
# 1993       229243
# 1994       240628
# 1995       245915
# 1996       250353
# 1997       244322
# 1998       253279
# 1999       259984
# 2000       259905
# 2001       255071
# 2002       260401
# 2003       260429
# 2004       245249
# 2005       238622
# 2006       237200
# 2007       237211
# 2008       239368
# 2009       247324
# 2010       242243
# 2011       239972
# 2012       234085
# 2013       229421
# 2014       227793
# 2015       207908
# 2016        16483

# %%
# menghapus baris 2016

df_year = df_year.drop(2016, axis=0)
df_year.tail()
# Out:
#       suicides_no
# year
# 2011       239972
# 2012       234085
# 2013       229421
# 2014       227793
# 2015       207908

# %%
# mendefinisikan nilai x dan y
x = list(df_year.index)
y = list(df_year['suicides_no'])

# %%
# visualisasi data dengan matplotlib

plt.plot(x,y)

# %%
con_countries = (df['country']=='Australia') | (df['country']=='Japan') | (df['country']=='Republic of Korea') | \
                (df['country']=='United Kingdom') | (df['country']=='United States of America')
    
con_years = (df['year']==2006) | (df['year']==2007) | (df['year']==2008) | (df['year']==2009) | (df['year']==2010) | \
            (df['year']==2011) | (df['year']==2012) | (df['year']==2013) | (df['year']==2014) | (df['year']==2015)

# %%
# membuat dataframe

df_choice = df[con_countries & con_years].reset_index(drop=True)
df_choice
# Out:
#                       country  year     sex          age  suicides_no  \
# 0                   Australia  2006  female  15-24 years           68
# 1                   Australia  2006  female  25-34 years           74
# 2                   Australia  2006  female  35-54 years          195
# 3                   Australia  2006  female   5-14 years            1
# 4                   Australia  2006  female  55-74 years          115
# ..                        ...   ...     ...          ...          ...
# 595  United States of America  2015    male  25-34 years         5503
# 596  United States of America  2015    male  35-54 years        11634
# 597  United States of America  2015    male   5-14 years          255
# 598  United States of America  2015    male  55-74 years         9068
# 599  United States of America  2015    male    75+ years         3171
#
#      population
# 0     1388615.0
# 1     1444570.0
# 2     2934459.0
# 3     1332380.0
# 4     1798232.0
# ..          ...
# 595  22137097.0
# 596  41658010.0
# 597  21273987.0
# 598  32264697.0
# 599   8171136.0
#
# [600 rows x 6 columns]

# %%
# transformasi menjadi pivot table

pivot_choice = df_choice.pivot_table(index='year', columns='country', values='suicides_no', aggfunc='sum')
pivot_choice
# Out:
# country  Australia  Japan  Republic of Korea  United Kingdom  \
# year
# 2006          2117  29769              10653            4122
# 2007          2229  30665              12174            3897
# 2008          2341  30073              12858            4259
# 2009          2337  30523              15402            4246
# 2010          2420  29411              15558            4188
# 2011          2392  28766              15906            4393
# 2012          2580  26338              14159            4444
# 2013          2608  25991              14426            4824
# 2014          2891  24357              13834            4788
# 2015          3027  23092              13510            4910
#
# country  United States of America
# year
# 2006                        33292
# 2007                        34596
# 2008                        36030
# 2009                        36900
# 2010                        38362
# 2011                        39508
# 2012                        40596
# 2013                        41143
# 2014                        42769
# 2015                        44189

# %%
# plotting data

pivot_choice.plot(kind='line')
# Out:
# <AxesSubplot: xlabel='year'>

# %%
# contoh pengaturan figure size
plt.style.use('ggplot')

# mengatur figure size
pivot_choice.plot(kind='line', figsize=(16,8))
plt.show()

# %%
# contoh pengaturan title
plt.style.use('ggplot')

pivot_choice.plot(kind='line', figsize=(16,8))

plt.title('WHO Suicides Statistics\n', size=25)
plt.show()

# %%
# contoh pengaturan label
plt.style.use('ggplot')

pivot_choice.plot(kind='line', figsize=(16,8))
plt.title('WHO Suicides Statistics\n', size=25)

# mengatur label pada sumbu x dan y
plt.ylabel('Number of suicide', size=20)
plt.xlabel('Years', size=20)
plt.show()

# %%
# contoh pengaturan ticks
plt.style.use('ggplot')

pivot_choice.plot(kind='line', figsize=(16,8))
plt.title('WHO Suicides Statistics\n', size=25)
plt.ylabel('Number of suicide', size=20)
plt.xlabel('Years', size=20)

# mengatur xticks dan yticks
plt.xticks(size=16)
plt.yticks(size=16)
plt.show()

# %%
# contoh pengaturan legend
plt.style.use('ggplot')

pivot_choice.plot(kind='line', figsize=(16,8))
plt.title('WHO Suicides Statistics\n', size=25)
plt.ylabel('Number of suicide', size=20)
plt.xlabel('Years', size=20)
plt.xticks(size=16)
plt.yticks(size=16)

# mengatur legend
plt.legend(prop={'size': 14})
plt.show()

# %%
# contoh pengaturan line color
plt.figure(figsize=(16,8))

plt.plot(x,y, color='orange')

plt.title('WHO Suicides Statistics Globally', size=25)
plt.ylabel('Number of suicide', size=20)
plt.xlabel('Years', size=20)
plt.xticks(size=16)
plt.yticks(size=16)
plt.show()

# %%
# contoh pengaturan line color
plt.figure(figsize=(16,8))

# mengatur line color dengan hexadecimal
plt.plot(x,y, color='#00685a')

plt.title('WHO Suicides Statistics Globally', size=25)
plt.ylabel('Number of suicide', size=20)
plt.xlabel('Years', size=20)
plt.xticks(size=16)
plt.yticks(size=16)
plt.show()

# %%
# contoh pengaturan line color
plt.figure(figsize=(16,8))

# mengatur line style
plt.plot(x,y, linestyle='dashed')

plt.title('WHO Suicides Statistics Globally', size=25)
plt.ylabel('Number of suicide', size=20)
plt.xlabel('Years', size=20)
plt.xticks(size=16)
plt.yticks(size=16)
plt.show()

# %%
# contoh pengaturan line color
plt.figure(figsize=(16,8))

# mengatur line width
plt.plot(x,y, linewidth='5')

plt.title('WHO Suicides Statistics Globally', size=25)
plt.ylabel('Number of suicide', size=20)
plt.xlabel('Years', size=20)
plt.xticks(size=16)
plt.yticks(size=16)
plt.show()

# %%
# contoh pengaturan line color
plt.figure(figsize=(16,8))

# mengatur line width
plt.plot(x,y, lw='15.5')

plt.title('WHO Suicides Statistics Globally', size=25)
plt.ylabel('Number of suicide', size=20)
plt.xlabel('Years', size=20)
plt.xticks(size=16)
plt.yticks(size=16)
plt.show()

# %%
# contoh pengaturan line color
plt.figure(figsize=(16,8))

# mengatur marker
plt.plot(x,y, marker='o')

plt.title('WHO Suicides Statistics Globally', size=25)
plt.ylabel('Number of suicide', size=20)
plt.xlabel('Years', size=20)
plt.xticks(size=16)
plt.yticks(size=16)
plt.show()

# %%
# contoh pengaturan line color
plt.figure(figsize=(16,8))

# mengatur line marker
plt.plot(x,y, marker='s')

plt.title('WHO Suicides Statistics Globally', size=25)
plt.ylabel('Number of suicide', size=20)
plt.xlabel('Years', size=20)
plt.xticks(size=16)
plt.yticks(size=16)
plt.show()
